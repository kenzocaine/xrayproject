# %% [markdown]
# The imports:

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from xrayproject.utils import load_train, load_masks
from xrayproject.preprocessing import normalize, flip_resize, resize_test
import matplotlib.pyplot as plt

# %% [markdown]
# ### Section 0.1: Calling funtions from previous modules/.py files in the xrayproject-project:

# %%
path_image = '../raw_data/raw_PRC/CXR_png/'
path_mask = '../raw_data/raw_PRC/CXR_mask/'

masks, targets, ID = load_masks(100, get_all = False, get_random = True, balanced = True, path = path_mask)
# Out:
# Using path:  ../raw_data/raw_PRC/CXR_mask/
# Using bucket
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0363_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0649_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0340_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0368_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0386_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0616_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0403_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0647_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0399_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0557_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0330_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0388_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0392_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0606_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0471_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0530_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0436_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0542_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0588_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0583_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0557_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0462_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0537_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0452_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0515_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0408_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0477_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0662_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0370_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0329_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0582_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0520_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0394_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0527_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0362_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0556_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0371_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0634_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0579_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0614_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0435_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0512_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0379_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0523_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0386_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0533_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0428_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0594_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0521_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0509_1_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0091_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0305_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0082_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0265_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0085_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0159_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0238_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0069_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0072_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0322_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0097_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0043_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0003_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0072_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0118_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0269_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0107_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0161_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0083_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0080_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0282_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0232_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0151_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0238_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0131_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0048_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0110_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0273_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0270_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0268_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0248_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0143_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0086_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0052_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0247_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0122_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0164_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0031_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0016_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0280_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0078_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0113_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0018_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0171_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0091_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0159_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0264_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0263_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0154_0_mask.png
# Loading local file:  ../raw_data/raw_PRC/CXR_mask/CHNCXR_0262_0_mask.png

# %%
1+1
# Out:
# 2

# %%
images, IDs = load_train(ID, path = path_image)
# Out:
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0537_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0452_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0083_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0262_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0556_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0043_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0399_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0305_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0594_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0161_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0428_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0340_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0634_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0379_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0238_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0238_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0280_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0614_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0515_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0408_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0264_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0435_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0078_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0085_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0122_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0616_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0362_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0533_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0282_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0386_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0386_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0143_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0080_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0118_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0509_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0247_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0322_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0512_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0557_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0557_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0263_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0477_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0082_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0363_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0003_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0086_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0436_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0107_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0530_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0588_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0649_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0018_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0265_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0164_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0471_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0159_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0159_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0110_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0048_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0269_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0270_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0171_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0579_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0091_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0091_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0016_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0647_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0527_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0392_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0523_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0403_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0097_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0582_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0462_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0606_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0542_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0370_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0394_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0151_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0521_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0052_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0273_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0113_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0662_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0268_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0031_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0329_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0154_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0330_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0388_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0131_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0069_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0248_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0371_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0520_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0368_1.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0072_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0072_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0232_0.png
# Loading local file:  ../raw_data/raw_PRC/CXR_png/CHNCXR_0583_1.png

# %%
print(images[1].shape)
# Out:
# (2965, 3000, 3)

# %%
2897/2499
# Out:
# 1.1592637054821928

# %%
print(images[1].shape)
# resized = [flip_resize(images[i], masks[i], input_shape=(4*116, 4*100)) for i in range(len(images))]
resized = [flip_resize(images[i], masks[i], input_shape=(128, 128)) for i in range(len(images))]
print(resized[0][0].shape)
# Out:
# (2965, 3000, 3)
# (128, 128, 3)

# %%
print(images[1].shape)
plt.imshow(images[1])
plt.show()

print(resized[1][0].shape)
plt.imshow(resized[1][0])
plt.show()

print(masks[1].shape)
plt.imshow(masks[1])
plt.show()

print(resized[1][1].shape)
plt.imshow(resized[1][1])
plt.show()
# Out:
# (2965, 3000, 3)
# (128, 128, 3)
# (2965, 3000, 1)
# (128, 128, 1)

# %%
plt.imshow(masks[1]*images[1])
plt.show()
plt.imshow(resized[1][0]*resized[1][1])
plt.show()

# %% [markdown]
# ### Implementing a train-test split. Not sure this is needed...

# %%
print(resized[0][0].shape,\
      resized[0][1].shape,\
      resized[0][2].shape,\
      resized[0][3].shape)
# Out:
# (128, 128, 3) (128, 128, 1) (128, 128, 3) (128, 128, 1)

# %%
X_1 = [img_mask_pair[0] for img_mask_pair in resized]
X_2 = [img_mask_pair[2] for img_mask_pair in resized]

Y_1 = [img_mask_pair[1] for img_mask_pair in resized]
Y_2 = [img_mask_pair[3] for img_mask_pair in resized]

X = X_1 + X_2
Y = Y_1 + Y_2

X = np.array(X)
Y = np.array(Y)

# X = tuple(X)
# Y = tuple(Y)

print(len(X))
print(len(Y))

plt.imshow(X[10])
plt.show()

plt.imshow(X[110])
plt.show()

plt.imshow(Y[10])
plt.show()

plt.imshow(Y[110])
plt.show()
# Out:
# 200
# 200

# %%
np.shape(X_1)
type(np.array(X_1))
type(X_1[0])
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
print(X_test.shape, X_train.shape)
print(Y_test.shape, Y_train.shape)
# Out:
# (60, 128, 128, 3) (140, 128, 128, 3)
# (60, 128, 128, 1) (140, 128, 128, 1)

# %% [markdown]
# ### Using some stolen plotting-functions, etc.:

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()

# %% [markdown]
# ### Defining the model (stolen direclty from <https://www.tensorflow.org/tutorials/images/segmentation>):
#
# **Note**: The models in this section seem to want square images. So I will make them square. Currently, I see two "safe" ways to do this:
#
# 1. Utilizing the tensorflow-method tf.image.resize_with_pad, one can simply resize all images to squares by adding blank-space to make them square. This sounds innocuous, but will certainly increase the "class imbalance, which *could* be problematic.
#
# 2. Simply resizing the images to squares. This also has pros and cons. Pro: The class imbalances will remain fixed/minimally horrible. Con: It will distort the images, which may degrade image-recognition.
#
# FYI: <https://www.tensorflow.org/api_docs/python/tf/image/resize_with_pad>

# %%
OUTPUT_CHANNELS = 1

# %% [markdown]
# **Important**: When the model _MobileNetV2_ is instantiated, _tensorflow_ gives error-messages unless two conditions are simulanteously met by the input_shape-parameter:
#
# 1. The input_shape is non-square. (We knew this. See above markup-cell.)
# 2. The input_shape is a square with dimensions other than (224, 224), (128, 128) etc. etc. The largest of these is (224, 224)-shape. But with (224, 224) there were problems --- maybe with the dimensionality of the "layer_names"-feature of the base_model (below). So I have chosen to futz that over to (128, 128)-shape for the time being...

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[128, 128, 3], include_top=False)

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)

down_stack.trainable = False

# %%
from tensorflow_examples.models.pix2pix import pix2pix

up_stack = [
    pix2pix.upsample(512, 3),  # 4x4 -> 8x8
    pix2pix.upsample(256, 3),  # 8x8 -> 16x16
    pix2pix.upsample(128, 3),  # 16x16 -> 32x32
    pix2pix.upsample(64, 3),   # 32x32 -> 64x64
]

# %%
def unet_model(output_channels):
  inputs = tf.keras.layers.Input(shape=[128, 128, 3])

  # Downsampling through the model
  skips = down_stack(inputs)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()
    x = concat([x, skip])

  # This is the last layer of the model
  last = tf.keras.layers.Conv2DTranspose(
      output_channels, 2, strides=2,
      padding='same')  #64x64 -> 128x128

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# ### Running the model (stolen directly and modified _zero_ (will it work at all??))...

# %%
model = unet_model(OUTPUT_CHANNELS)
model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
def create_mask(pred_mask):
  pred_mask = tf.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

# %%
# class DisplayCallback(tf.keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs=None):
#     clear_output(wait=True)
#     show_predictions()
#     print ('\nSample Prediction after epoch {}\n'.format(epoch+1))

# %%
len(resized[1])
# Out:
# 4

# %%
TRAIN_LENGTH = len(X_test)
BATCH_SIZE = 5
BUFFER_SIZE = 10
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
x_train = tf.image.rgb_to_grayscale(X_train)
x_test = tf.image.rgb_to_grayscale(X_test)

# %%
train_dataset = (x_train, Y_train)
test_dataset = (x_test, Y_test)

# %%
np.shape(train_dataset)
# Out:
# (2, 140, 128, 128, 1)

# %%
np.shape(X_train)
# Out:
# (140, 128, 128, 3)

# %%
Y_train.shape
# Out:
# (140, 128, 128, 1)

# %%
EPOCHS = 50
VAL_SUBSPLITS = 5
VALIDATION_STEPS = len(X_test)//BATCH_SIZE//VAL_SUBSPLITS

model_history = model.fit(X_train, Y_train, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=(X_test, Y_test)#,
#                           callbacks=[DisplayCallback()]
                         )
# Out:
# Epoch 1/50
# 12/12 [==============================] - 12s 773ms/step - loss: 0.6336 - accuracy: 0.7295 - val_loss: 0.3402 - val_accuracy: 0.8698
# Epoch 2/50
# 12/12 [==============================] - 9s 727ms/step - loss: 0.3588 - accuracy: 0.8106 - val_loss: 0.2078 - val_accuracy: 0.9215
# Epoch 3/50
# 12/12 [==============================] - 9s 755ms/step - loss: 0.2769 - accuracy: 0.8349 - val_loss: 0.1692 - val_accuracy: 0.9418
# Epoch 4/50
# 12/12 [==============================] - 9s 755ms/step - loss: 0.2111 - accuracy: 0.9171 - val_loss: 0.1469 - val_accuracy: 0.9644
# Epoch 5/50
# 12/12 [==============================] - 9s 779ms/step - loss: 0.1683 - accuracy: 0.9527 - val_loss: 0.1365 - val_accuracy: 0.9585
# Epoch 6/50
# 12/12 [==============================] - 10s 818ms/step - loss: 0.1382 - accuracy: 0.9626 - val_loss: 0.1356 - val_accuracy: 0.9517
# Epoch 7/50
# 12/12 [==============================] - 10s 813ms/step - loss: 0.1159 - accuracy: 0.9682 - val_loss: 0.1422 - val_accuracy: 0.9431
# Epoch 8/50
# 12/12 [==============================] - 9s 755ms/step - loss: 0.0969 - accuracy: 0.9734 - val_loss: 0.1358 - val_accuracy: 0.9461
# Epoch 9/50
# 12/12 [==============================] - 9s 748ms/step - loss: 0.0863 - accuracy: 0.9758 - val_loss: 0.1395 - val_accuracy: 0.9433
# Epoch 10/50
# 12/12 [==============================] - 9s 735ms/step - loss: 0.0801 - accuracy: 0.9768 - val_loss: 0.1599 - val_accuracy: 0.9250
# Epoch 11/50
# 12/12 [==============================] - 9s 792ms/step - loss: 0.0723 - accuracy: 0.9775 - val_loss: 0.1438 - val_accuracy: 0.9370
# Epoch 12/50
# 12/12 [==============================] - 9s 744ms/step - loss: 0.0659 - accuracy: 0.9789 - val_loss: 0.1389 - val_accuracy: 0.9407
# Epoch 13/50
# 12/12 [==============================] - 9s 746ms/step - loss: 0.0620 - accuracy: 0.9789 - val_loss: 0.1352 - val_accuracy: 0.9425
# Epoch 14/50
# 12/12 [==============================] - 9s 745ms/step - loss: 0.0574 - accuracy: 0.9807 - val_loss: 0.1502 - val_accuracy: 0.9318
# Epoch 15/50
# 12/12 [==============================] - 9s 782ms/step - loss: 0.0528 - accuracy: 0.9828 - val_loss: 0.1310 - val_accuracy: 0.9447
# Epoch 16/50
# 12/12 [==============================] - 9s 779ms/step - loss: 0.0511 - accuracy: 0.9830 - val_loss: 0.1168 - val_accuracy: 0.9530
# Epoch 17/50
# 12/12 [==============================] - 9s 740ms/step - loss: 0.0498 - accuracy: 0.9823 - val_loss: 0.1362 - val_accuracy: 0.9428
# Epoch 18/50
# 12/12 [==============================] - 9s 725ms/step - loss: 0.0438 - accuracy: 0.9844 - val_loss: 0.1172 - val_accuracy: 0.9531
# Epoch 19/50
# 12/12 [==============================] - 9s 728ms/step - loss: 0.0414 - accuracy: 0.9856 - val_loss: 0.1192 - val_accuracy: 0.9511
# Epoch 20/50
# 12/12 [==============================] - 9s 727ms/step - loss: 0.0402 - accuracy: 0.9848 - val_loss: 0.1212 - val_accuracy: 0.9505
# Epoch 21/50
# 12/12 [==============================] - 9s 727ms/step - loss: 0.0381 - accuracy: 0.9855 - val_loss: 0.0948 - val_accuracy: 0.9634
# Epoch 22/50
# 12/12 [==============================] - 9s 724ms/step - loss: 0.0365 - accuracy: 0.9866 - val_loss: 0.0893 - val_accuracy: 0.9659
# Epoch 23/50
# 12/12 [==============================] - 9s 746ms/step - loss: 0.0352 - accuracy: 0.9868 - val_loss: 0.0962 - val_accuracy: 0.9623
# Epoch 24/50
# 12/12 [==============================] - 9s 728ms/step - loss: 0.0332 - accuracy: 0.9878 - val_loss: 0.1005 - val_accuracy: 0.9604
# Epoch 25/50
# 12/12 [==============================] - 9s 776ms/step - loss: 0.0314 - accuracy: 0.9877 - val_loss: 0.1037 - val_accuracy: 0.9590
# Epoch 26/50
# 12/12 [==============================] - 9s 746ms/step - loss: 0.0303 - accuracy: 0.9880 - val_loss: 0.0881 - val_accuracy: 0.9668
# Epoch 27/50
# 12/12 [==============================] - 8s 716ms/step - loss: 0.0299 - accuracy: 0.9892 - val_loss: 0.0915 - val_accuracy: 0.9645
# Epoch 28/50
# 12/12 [==============================] - 9s 739ms/step - loss: 0.0286 - accuracy: 0.9887 - val_loss: 0.0877 - val_accuracy: 0.9665
# Epoch 29/50
# 12/12 [==============================] - 9s 767ms/step - loss: 0.0277 - accuracy: 0.9898 - val_loss: 0.0974 - val_accuracy: 0.9631
# Epoch 30/50
# 12/12 [==============================] - 9s 743ms/step - loss: 0.0256 - accuracy: 0.9901 - val_loss: 0.0861 - val_accuracy: 0.9676
# Epoch 31/50
# 12/12 [==============================] - 9s 744ms/step - loss: 0.0237 - accuracy: 0.9908 - val_loss: 0.0861 - val_accuracy: 0.9678
# Epoch 32/50
# 12/12 [==============================] - 9s 725ms/step - loss: 0.0233 - accuracy: 0.9913 - val_loss: 0.0786 - val_accuracy: 0.9714
# Epoch 33/50
# 12/12 [==============================] - 9s 730ms/step - loss: 0.0229 - accuracy: 0.9915 - val_loss: 0.0825 - val_accuracy: 0.9699
# Epoch 34/50
# 12/12 [==============================] - 9s 728ms/step - loss: 0.0225 - accuracy: 0.9918 - val_loss: 0.0897 - val_accuracy: 0.9665
# Epoch 35/50
# 12/12 [==============================] - 9s 780ms/step - loss: 0.0216 - accuracy: 0.9912 - val_loss: 0.0885 - val_accuracy: 0.9676
# Epoch 36/50
# 12/12 [==============================] - 9s 796ms/step - loss: 0.0207 - accuracy: 0.9914 - val_loss: 0.0850 - val_accuracy: 0.9686
# Epoch 37/50
# 12/12 [==============================] - 10s 897ms/step - loss: 0.0191 - accuracy: 0.9923 - val_loss: 0.0771 - val_accuracy: 0.9722
# Epoch 38/50
# 12/12 [==============================] - 9s 725ms/step - loss: 0.0191 - accuracy: 0.9927 - val_loss: 0.0808 - val_accuracy: 0.9710
# Epoch 39/50
# 12/12 [==============================] - 9s 735ms/step - loss: 0.0192 - accuracy: 0.9918 - val_loss: 0.0809 - val_accuracy: 0.9713
# Epoch 40/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.0184 - accuracy: 0.9926 - val_loss: 0.0790 - val_accuracy: 0.9723
# Epoch 41/50
# 12/12 [==============================] - 11s 910ms/step - loss: 0.0172 - accuracy: 0.9935 - val_loss: 0.0802 - val_accuracy: 0.9721
# Epoch 42/50
# 12/12 [==============================] - 10s 888ms/step - loss: 0.0164 - accuracy: 0.9938 - val_loss: 0.0790 - val_accuracy: 0.9731
# Epoch 43/50
# 12/12 [==============================] - 11s 924ms/step - loss: 0.0183 - accuracy: 0.9931 - val_loss: 0.0901 - val_accuracy: 0.9692
# Epoch 44/50
# 12/12 [==============================] - 11s 871ms/step - loss: 0.0177 - accuracy: 0.9925 - val_loss: 0.0821 - val_accuracy: 0.9722
# Epoch 45/50
# 12/12 [==============================] - 14s 1s/step - loss: 0.0165 - accuracy: 0.9933 - val_loss: 0.0837 - val_accuracy: 0.9722
# Epoch 46/50
# 12/12 [==============================] - 10s 789ms/step - loss: 0.0179 - accuracy: 0.9921 - val_loss: 0.0859 - val_accuracy: 0.9709
# Epoch 47/50
# 12/12 [==============================] - 11s 936ms/step - loss: 0.0156 - accuracy: 0.9935 - val_loss: 0.0820 - val_accuracy: 0.9724
# Epoch 48/50
# 12/12 [==============================] - 10s 806ms/step - loss: 0.0140 - accuracy: 0.9946 - val_loss: 0.0805 - val_accuracy: 0.9738
# Epoch 49/50
# 12/12 [==============================] - 12s 988ms/step - loss: 0.0142 - accuracy: 0.9946 - val_loss: 0.0790 - val_accuracy: 0.9743
# Epoch 50/50
# 12/12 [==============================] - 11s 913ms/step - loss: 0.0130 - accuracy: 0.9950 - val_loss: 0.0825 - val_accuracy: 0.9736

# %%
# loss = model_history.history['loss']
# val_loss = model_history.history['val_loss']

# plt.figure()
# plt.plot(model_history.epoch, loss, 'r', label='Training loss')
# plt.plot(model_history.epoch, val_loss, 'bo', label='Validation loss')
# plt.title('Training and Validation Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss Value')
# plt.ylim([0, 1])
# plt.legend()
# plt.show()

# %%
# show_predictions(X_test, 3)

# %%
plt.imshow(X_test[1]*Y_test[1])
plt.show()

plt.imshow(Y_test[1])
plt.show()

# %%
plt.imshow(model.predict(X_test[1]))

# %%
X_test[1].shape
