# %%
# %load_ext autoreload
# %autoreload 2
from xrayproject.utils import load_pngs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img, target = load_pngs(10, get_all = False, get_random = False, balanced = False)
# Out:
# /Users/kimhedelin/code/kenzocaine/xrayproject/xrayproject/../raw_data/ChinaSet_AllFiles/CXR_png/

# %%
import sys
sys.path
# Out:
# ['/Users/kimhedelin/code/kenzocaine/xrayproject/notebooks',
#  '/Users/kimhedelin/code/kenzocaine/data-challenges/04-Decision-Science',
#  '/Users/kimhedelin/code/kenzocaine/xrayproject/notebooks',
#  '/Users/kimhedelin/.pyenv/versions/3.8.6/lib/python38.zip',
#  '/Users/kimhedelin/.pyenv/versions/3.8.6/lib/python3.8',
#  '/Users/kimhedelin/.pyenv/versions/3.8.6/lib/python3.8/lib-dynload',
#  '',
#  '/Users/kimhedelin/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages',
#  '/Users/kimhedelin/code/kenzocaine/mlproject',
#  '/Users/kimhedelin/code/kenzocaine/xrayproject',
#  '/Users/kimhedelin/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/kimhedelin/.ipython']

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize = (10,10))
for i in range(2):
    plt.subplot(2,2,i+1)
    plt.imshow(positive[i])

for i in range(2):
    plt.subplot(2,2,i+3)
    plt.imshow(negative[i])

# %%
targets
# Out:
# ['1', '0', '1']

# %%
len(img)
# Out:
# 3
