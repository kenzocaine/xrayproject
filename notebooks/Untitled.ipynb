# %%
# %load_ext autoreload
# %autoreload 2
from xrayproject.utils import load_pngs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img, targets = load_pngs(3, get_all = False)

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize = (10,10))
for i in range(3):
    plt.subplot(3,1,i+1)
    plt.imshow(img[i])

# %%
targets
# Out:
# ['1', '0', '1']

# %%
len(img)
# Out:
# 3
